# %% [markdown]
# # 4. Reduciendo la brecha de acceso a Internet en población de escasos recursos

# %% [markdown]
# ## 4.1 Contexto

# %% [markdown]
# Buenaventura es una ciudad que enfrenta importantes desafíos en el acceso a infraestructura de comunicación digital, quedando rezagada frente a otras ciudades del país. Según el Ministerio de Tecnologías de la Información y las Comunicaciones, en el año 2020 el 56% de la población de Buenaventura no tenía acceso a Internet. Esta situación evidencia una brecha digital que impacta especialmente a las comunidades más vulnerables, limitando su acceso a servicios esenciales como educación, salud, empleo y entretenimiento en línea.
#
# Para reducir esta brecha digital, es crucial invertir en el desarrollo de infraestructuras de conectividad. Sin embargo, las condiciones geográficas de Buenaventura imponen desafíos adicionales, ya que los recursos económicos son limitados y no siempre es viable implementar soluciones inalámbricas de alta velocidad en todos los puntos de acceso. Por este motivo, la instalación de cableado se vuelve indispensable, lo que a menudo implica atravesar zonas marinas.
#
# En este contexto, se te propone construir un modelo que describa el desgaste del material del cableado —medido en términos de su diámetro— en función del tiempo que permanece bajo el agua.

# %% [markdown]
# ![_2fbed608-cdac-4b38-b439-94c831a6a156.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 4.2 Tema
#
#
#
# ## 4.3  Objetivo
#
# Diseñar e implementar computacionalmente un modelo matemático que permita estimar el desgaste de material de un cable submarino (con respecto al tamaño del diámetro del cable) en función del tiempo de permanencia en el agua.

# %% [markdown]
# ## 3.4 Actividad

# %% [markdown]
# ### 4.4.1  Análisis de costos de mantenimiento y actualización de software a largo plazo
#
# En un estudio sobre el desgaste del cableado submarino utilizado para mejorar la conectividad en Buenaventura, se determinó que el diámetro del cable (en mm) disminuye linealmente con el tiempo debido a la corrosión. Al inicio de su instalación, el cable tiene un diámetro de 50 mm, y después de 5 años bajo el agua, su diámetro se reduce a 47 mm. ¿cuánto tiempo pasará hasta que el cable alcance un diámetro crítico de 40 mm?

# %% [markdown]
# #### 4.4.1.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema. (**pista** ¿Qué significa que disminuye linealmente?) Describe las variables, datos y reglas que identificas en el problema.

# %% [markdown]
# 2. **Planear la solución.** ¿Qué pasos debes seguir para resolver el problema?
#         Describe tu estrategia para resolver el problema

# %% [markdown]
# 3. **Ejecutar el plan.** En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software.
# Si necesitas puedes usar python como calculadora para realizar los cálculos necesarios.

# %% [markdown]
# 4. **Examinar la solución obtenida** Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso. ¿Por qué crees que tu solución esta correcta?

# %% [markdown]
# ### 4.4.2 Jugando con el computador!
#
# #### Actividad: Explorando la vida útil del cable
#
# Imagina que en Buenaventura se utiliza un cable submarino para transmitir datos. El cable tiene dos aspectos importantes:
#
# 1. **Temperatura del cable:**
#    La temperatura depende del flujo de datos $D$ (en unidades arbitrarias) según la función:
#    $$
#    T(D) = 8D + B,
#    $$
#    donde $B$ es una constante que se puede ajustar. El cable tiene una **temperatura crítica** de $T_c = 50^\circ$ grados, temperatura en la cual el cable empieza a derretirse y por lo tanto debe evitarse.
#
# 2. **Capacidad máxima de transmisión**
#    El envejecimiento del cable submarino es un problema importante en la transmisión de datos, ya que la capacidad de transmisión disminuye con el tiempo. La capacidad de transmisión del cable se puede modelar como una función lineal en función del tiempo $t$ en años:
#
#   $$
#    D(t) = -\frac{1}{3}t + 10,
# $$
#    donde $t$ es el tiempo en años  y la función $D(t)$ representa la capacidad máxima de transmisión de datos en unidades arbitrarias. Para la empresa es viable que la capacidad máxima de transmisión de datos  sea mayor a $D_c=5$, de lo contrario la empresa asumiría perdidas.
#
# ## Pregunta
#
# **Los ingenieros se preguntan ¿en cuanto tiempo la capacidad máxima de flujo de datos produce la temperatura crítica del cable, para diferentes valores de $B$ con $B\in[0,20]$?**

# %%
import requests
# URL del archivo
url = "https://raw.githubusercontent.com/abelalv/libreria_2025/refs/heads/main/MMAF.py"
# Descargar el archivo
response = requests.get(url)
with open('MMAF.py', 'w', encoding='utf-8') as file:
    file.write(response.text)

# %%
from MMAF import interactuar_con_temperatura, interactuar_con_desgaste

# Slider de temperatura
interactuar_con_temperatura()
# Out:
# interactive(children=(FloatSlider(value=10.0, description='Parámetro B', max=20.0, step=0.5), Output()), _dom_…
# <function MMAF.mostrar_temperatura(B)>

# %%
# Slider de desgaste
interactuar_con_desgaste()
# Out:
# interactive(children=(FloatSlider(value=5.0, description='Capacidad Crítica D_c', max=10.0), Output()), _dom_c…
# <function MMAF.mostrar_desgaste(D_c)>

# %% [markdown]
# #### 3.4.2.1 Manos a la obra

# %% [markdown]
# 1. **Comprender el problema.** En esta etapa se busca comprender bien el problema que se quiere resolver e identificar las variables, datos y reglas relevantes para solucionar el problema.

# %% [markdown]
# 2. **Planear la solución.** En esta etapa se busca identificar los pasos necesarios para resolver el problema y seleccionar la mejor estrategia para hacerlo.

# %% [markdown]
# 3. **Ejecutar el plan.** En esta etapa deberías ejecutar la estrategia identificada en el paso anterior usando herramientas matemáticas, posiblemente asistidas por software.

# %% [markdown]
# 4. **Examinar la solución obtenida** Siempre que encuentres una solución de un problema es importante asegurarte que los resultados obtenido sean acordes  a las condiciones  iniciales del problema, factibles y en el caso contrario deberías regresar el primer paso.

# %% [markdown]
# **Bonus** Es posible encontrar la tasa de variación de la temperatura en función del flujo de datos D, y la tasa de variación de la capacidad de transmisión en función del tiempo t.

# %% [markdown]
# Solucion

# %% [markdown]
# ### Vida útil del cable submarino
# ### Solucion <"">
#
# 1. Entender el problema
# El cable se va desgastando con el tiempo, reduciendo su diámetro de manera constante. Queremos saber en cuánto tiempo alcanzará un diámetro crítico. También debemos analizar cómo la temperatura y la capacidad de transmisión cambian con el tiempo.
#
# 2. Planear la solución
# Encontrar la velocidad a la que el diámetro disminuye. Usar la ecuación dada para calcular el tiempo en que llegará al límite crítico. Para la temperatura, despejar el flujo de datos que la lleva al máximo permitido. Para la capacidad de transmisión, encontrar cuándo baja demasiado.
#
# 3. Ejecutar el plan
# Calcular cuánto se reduce el diámetro por unidad de tiempo. Aplicar la ecuación de temperatura para diferentes condiciones. Reorganizar la ecuación de capacidad de transmisión para hallar el tiempo crítico.
#
# 4. Revisar la solución
# Verificar que los valores obtenidos sean lógicos. Asegurar que las ecuaciones usadas realmente describen el problema.

# %% [markdown]
# explicacion del codigo:

# %% [markdown]
# El código estudia cómo la temperatura de un cable cambia con el flujo de datos y cómo su capacidad de transmisión disminuye con el tiempo.
#
# Primero, la temperatura del cable sube cuando hay más datos. Si un factor externo es alto, el cable se calienta más rápido y soporta menos flujo antes de llegar a su límite.
#
# Luego el código muestra que con el tiempo el cable se desgasta y pierde capacidad de transmitir datos. Si el desgaste es rápido, el cable deja de funcionar antes.
#
# En resumen si hay mucho flujo o el desgaste es grande, el cable se calienta y pierde capacidad más rápido.
